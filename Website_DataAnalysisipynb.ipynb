# Out:
# Price           Close       High        Low       Open    Volume
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS 601138.SS
# Date
# 2018-11-09  10.622587  10.743102  10.605370  10.631196  13961168
# 2018-11-12  10.837794  10.846403  10.596763  10.613979  22176360
# 2018-11-13  10.906660  10.984135  10.631196  10.648412  34103393
# 2018-11-14  10.829186  11.001351  10.820578  10.906661  25854575
# 2018-11-15  11.096042  11.130475  10.803361  10.811969  42473501
# 2018-11-16  11.070216  11.156299  10.992743  11.113258  35226540
# 2018-11-19  11.207950  11.242383  11.009959  11.096042  33478260
# 2018-11-20  10.863619  11.130475  10.837794  11.104650  30572833
# 2018-11-21  10.777537  10.837795  10.674238  10.743104  19255414
# 2018-11-22  10.700063  10.820578  10.682846  10.777537  17918921
# 2018-11-23  10.166351  10.734496  10.140526  10.725888  33461384
# 2018-11-26  10.097484  10.252433  10.071659  10.166350  13373511
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1623 entries, 2018-06-13 to 2025-02-25
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   (Close, 601138.SS)   1623 non-null   float64
#  1   (High, 601138.SS)    1623 non-null   float64
#  2   (Low, 601138.SS)     1623 non-null   float64
#  3   (Open, 601138.SS)    1623 non-null   float64
#  4   (Volume, 601138.SS)  1623 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 76.1 KB

# %%
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume  \
# Ticker    601138.SS    601138.SS    601138.SS    601138.SS     601138.SS
# count   1623.000000  1623.000000  1623.000000  1623.000000  1.623000e+03
# mean      14.009256    14.263927    13.746343    13.988795  7.547769e+07
# std        4.803707     4.957857     4.635399     4.783829  7.332706e+07
# min        7.746119     7.831554     7.404379     7.470828  0.000000e+00
# 25%       10.573170    10.707295    10.454934    10.581936  2.497663e+07
# 50%       12.496474    12.697790    12.311275    12.488918  4.597884e+07
# 75%       15.926273    16.273277    15.576675    15.872393  1.008404e+08
# max       28.213284    28.670532    27.649018    28.651076  6.332171e+08
#
# Price    simple_rtn     clog_rtn
# Ticker
# count   1622.000000  1622.000000
# mean       0.000425     0.000028
# std        0.028291     0.028148
# min       -0.130543    -0.139887
# 25%       -0.013473    -0.013565
# ...

# %%
df.min()
# Out:
# Price       Ticker
# Close       601138.SS    7.746119
# High        601138.SS    7.831554
# Low         601138.SS    7.404379
# Open        601138.SS    7.470828
# Volume      601138.SS    0.000000
# simple_rtn              -0.130543
# clog_rtn                -0.139887
# dtype: float64

# %%
df.max()
# Out:
# Price       Ticker
# Close       601138.SS    2.821328e+01
# High        601138.SS    2.867053e+01
# Low         601138.SS    2.764902e+01
# Open        601138.SS    2.865108e+01
# Volume      601138.SS    6.332171e+08
# simple_rtn               1.052631e-01
# clog_rtn                 1.000834e-01
# dtype: float64

# %%
df.std()
# Out:
# Price       Ticker
# Close       601138.SS    4.803707e+00
# High        601138.SS    4.957857e+00
# Low         601138.SS    4.635399e+00
# Open        601138.SS    4.783829e+00
# Volume      601138.SS    7.332706e+07
# simple_rtn               2.829055e-02
# clog_rtn                 2.814751e-02
# dtype: float64

# %%
df['Close'].plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Date'>

# %%
df['Volume'].plot(figsize=(20,8))
# Out:
# <Axes: xlabel='Date'>

# %%
df[['Close','Volume']].plot(subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
df['simple_rtn']=df.Close.pct_change()
df['simple_rtn']
# Out:
# Date
# 2018-06-13   NaN
# 2018-06-14   NaN
# 2018-06-15   NaN
# 2018-06-19   NaN
# 2018-06-20   NaN
#               ..
# 2025-02-19   NaN
# 2025-02-20   NaN
# 2025-02-21   NaN
# 2025-02-24   NaN
# 2025-02-25   NaN
# Name: simple_rtn, Length: 1623, dtype: float64

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140432  22.691362  20.281049  21.133266  633217109        NaN
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105        NaN
# 2018-06-15  19.437443  19.910896  18.955381  19.454660  213870016        NaN
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713        NaN
# 2018-06-20  17.095999  17.440329  16.364297  17.044348  198271914        NaN
# ...               ...        ...        ...        ...        ...        ...
# 2025-02-19  23.240000  23.639999  22.549999  22.600000  197765185        NaN
# 2025-02-20  22.620001  23.110001  22.580000  23.049999  148493316        NaN
# 2025-02-21  23.200001  23.299999  22.590000  22.870001  202636966        NaN
# 2025-02-24  23.209999  23.959999  22.799999  23.379999  236870254        NaN
# ...

# %%
import numpy as np
df['clog_rtn']=np.log(df.Close/df.Close.shift(1))
df['clog_rtn']
# Out:
# Date
# 2018-06-13   NaN
# 2018-06-14   NaN
# 2018-06-15   NaN
# 2018-06-19   NaN
# 2018-06-20   NaN
#               ..
# 2025-02-19   NaN
# 2025-02-20   NaN
# 2025-02-21   NaN
# 2025-02-24   NaN
# 2025-02-25   NaN
# Name: clog_rtn, Length: 1623, dtype: float64

# %%
df['Volume'].plot(figsize=(20,8),title='TCS')
# Out:
# <Axes: title={'center': 'TCS'}, xlabel='Date'>

# %%
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume  \
# Ticker    601138.SS    601138.SS    601138.SS    601138.SS     601138.SS
# count   1623.000000  1623.000000  1623.000000  1623.000000  1.623000e+03
# mean      14.009256    14.263927    13.746343    13.988795  7.547769e+07
# std        4.803707     4.957857     4.635399     4.783829  7.332706e+07
# min        7.746119     7.831554     7.404379     7.470828  0.000000e+00
# 25%       10.573170    10.707295    10.454934    10.581936  2.497663e+07
# 50%       12.496473    12.697791    12.311275    12.488919  4.597884e+07
# 75%       15.926273    16.273278    15.576675    15.872393  1.008404e+08
# max       28.213284    28.670532    27.649018    28.651076  6.332171e+08
#
# Price    simple_rtn     clog_rtn
# Ticker
# count   1622.000000  1622.000000
# mean       0.000425     0.000028
# std        0.028291     0.028148
# min       -0.130543    -0.139887
# 25%       -0.013473    -0.013565
# ...

# %%
df.isnull().sum()
# Out:
# Price       Ticker
# Close       601138.SS       0
# High        601138.SS       0
# Low         601138.SS       0
# Open        601138.SS       0
# Volume      601138.SS       0
# simple_rtn               1623
# clog_rtn                 1623
# dtype: int64

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140438  22.691368  20.281055  21.133272  633217109        NaN
# 2018-06-14  20.048628  21.400124  19.928111  21.098834  347782105        NaN
# 2018-06-15  19.437443  19.910896  18.955381  19.454660  213870016        NaN
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713        NaN
# 2018-06-20  17.095997  17.440327  16.364295  17.044346  198271914        NaN
# ...               ...        ...        ...        ...        ...        ...
# 2025-02-19  23.240000  23.639999  22.549999  22.600000  197765185        NaN
# 2025-02-20  22.620001  23.110001  22.580000  23.049999  148493316        NaN
# 2025-02-21  23.200001  23.299999  22.590000  22.870001  202636966        NaN
# 2025-02-24  23.209999  23.959999  22.799999  23.379999  236870254        NaN
# ...

# %%
df['Volume_rtn'] = df.Volume.pct_change()

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140438  22.691368  20.281055  21.133272  633217109        NaN
# 2018-06-14  20.048628  21.400124  19.928111  21.098834  347782105        NaN
# 2018-06-15  19.437443  19.910896  18.955381  19.454660  213870016        NaN
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713        NaN
# 2018-06-20  17.095997  17.440327  16.364295  17.044346  198271914        NaN
# ...               ...        ...        ...        ...        ...        ...
# 2025-02-19  23.240000  23.639999  22.549999  22.600000  197765185        NaN
# 2025-02-20  22.620001  23.110001  22.580000  23.049999  148493316        NaN
# 2025-02-21  23.200001  23.299999  22.590000  22.870001  202636966        NaN
# 2025-02-24  23.209999  23.959999  22.799999  23.379999  236870254        NaN
# ...

# %%
df[['simple_rtn','Volume_rtn']].plot(subplots=True,style='b',figsize=(20,8))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140438  22.691368  20.281055  21.133272  633217109        NaN
# 2018-06-14  20.048628  21.400124  19.928111  21.098834  347782105        NaN
# 2018-06-15  19.437443  19.910896  18.955381  19.454660  213870016        NaN
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713        NaN
# 2018-06-20  17.095997  17.440327  16.364295  17.044346  198271914        NaN
# ...               ...        ...        ...        ...        ...        ...
# 2025-02-19  23.240000  23.639999  22.549999  22.600000  197765185        NaN
# 2025-02-20  22.620001  23.110001  22.580000  23.049999  148493316        NaN
# 2025-02-21  23.200001  23.299999  22.590000  22.870001  202636966        NaN
# 2025-02-24  23.209999  23.959999  22.799999  23.379999  236870254        NaN
# ...

# %%
df['log_rtn'] = np.log(df.Volume/df.Volume.shift(1))
df
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140432  22.691362  20.281049  21.133266  633217109        NaN
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105  -0.094479
# 2018-06-15  19.437443  19.910896  18.955381  19.454660  213870016  -0.030485
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713  -0.100089
# 2018-06-20  17.095999  17.440329  16.364297  17.044348  198271914  -0.022638
# ...               ...        ...        ...        ...        ...        ...
# 2025-02-19  23.240000  23.639999  22.549999  22.600000  197765185   0.024691
# 2025-02-20  22.620001  23.110001  22.580000  23.049999  148493316  -0.026678
# ...

# %%
df[['log_rtn','clog_rtn']].plot(subplots=True,style='b',figsize=(20,8))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
WINDOW_SIZE = 12
df['rolling_mean'] = df.Close.rolling(window=WINDOW_SIZE).mean()
df['rolling_std'] = df.Close.rolling(window=WINDOW_SIZE).std()

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140432  22.691362  20.281049  21.133266  633217109        NaN
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105  -0.094479
# 2018-06-15  19.437443  19.910896  18.955381  19.454660  213870016  -0.030485
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713  -0.100089
# 2018-06-20  17.095999  17.440329  16.364297  17.044348  198271914  -0.022638
# ...               ...        ...        ...        ...        ...        ...
# 2025-02-19  23.240000  23.639999  22.549999  22.600000  197765185   0.024691
# 2025-02-20  22.620001  23.110001  22.580000  23.049999  148493316  -0.026678
# 2025-02-21  23.200001  23.299999  22.590000  22.870001  202636966   0.025641
# 2025-02-24  23.209999  23.959999  22.799999  23.379999  236870254   0.000431
# ...

# %%
WINDOW_SIZE = 12
df['vrolling_mean'] = df.Volume.rolling(window=WINDOW_SIZE).mean()
df['vrolling_std'] = df.Volume.rolling(window=WINDOW_SIZE).std()

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140432  22.691362  20.281049  21.133266  633217109        NaN
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105        NaN
# 2018-06-15  19.437443  19.910896  18.955381  19.454660  213870016        NaN
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713        NaN
# 2018-06-20  17.095999  17.440329  16.364297  17.044348  198271914        NaN
# ...               ...        ...        ...        ...        ...        ...
# 2025-02-19  23.240000  23.639999  22.549999  22.600000  197765185        NaN
# 2025-02-20  22.620001  23.110001  22.580000  23.049999  148493316        NaN
# 2025-02-21  23.200001  23.299999  22.590000  22.870001  202636966        NaN
# 2025-02-24  23.209999  23.959999  22.799999  23.379999  236870254        NaN
# ...

# %%
df[:100]
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140432  22.691362  20.281049  21.133266  633217109        NaN
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105  -0.094479
# 2018-06-15  19.437443  19.910896  18.955381  19.454660  213870016  -0.030485
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713  -0.100089
# 2018-06-20  17.095999  17.440329  16.364297  17.044348  198271914  -0.022638
# ...               ...        ...        ...        ...        ...        ...
# 2018-11-02  10.855010  10.966917  10.648412  10.889443   49601038   0.021052
# 2018-11-05  10.846403  10.975527  10.725887  10.863619   35546773  -0.000793
# 2018-11-06  11.009959  11.061609  10.596763  10.760320   39011940   0.015079
# 2018-11-07  10.786145  11.053002  10.725888  10.949703   31397467  -0.020328
# ...

# %%
df[:20]
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140432  22.691362  20.281049  21.133266  633217109        NaN
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105        NaN
# 2018-06-15  19.437443  19.910896  18.955381  19.454660  213870016        NaN
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713        NaN
# 2018-06-20  17.095999  17.440329  16.364297  17.044348  198271914        NaN
# 2018-06-21  15.641202  17.027132  15.537902  16.872183  197849535        NaN
# 2018-06-22  16.114656  16.510637  15.090275  15.236615  175575007        NaN
# 2018-06-25  15.675632  16.149087  15.606766  16.028571  115443049        NaN
# 2018-06-26  15.951100  16.063007  15.107490  15.271047  113725844        NaN
# 2018-06-27  15.727284  16.235172  15.649810  15.925274   97039103        NaN
# ...

# %%
df[['rolling_mean','vrolling_mean']].plot(figsize=(20,8),style='b',subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
df['logrolling_mean']=np.log(df.rolling_mean/df.rolling_mean.shift(1))
df['logrolling_std']=np.log(df.rolling_std/df.rolling_std.shift(1))

# %%
df['logvrolling_mean']=np.log(df.rolling_mean/df.rolling_mean.shift(1))
df['logvrolling_std']=np.log(df.rolling_std/df.rolling_std.shift(1))

# %%
df
# Out:
# Price           Close       High        Low       Open     Volume simple_rtn  \
# Ticker      601138.SS  601138.SS  601138.SS  601138.SS  601138.SS
# Date
# 2018-06-13  22.140432  22.691362  20.281049  21.133266  633217109        NaN
# 2018-06-14  20.048630  21.400126  19.928113  21.098836  347782105        NaN
# 2018-06-15  19.437443  19.910896  18.955381  19.454660  213870016        NaN
# 2018-06-19  17.491976  18.791823  17.491976  18.791823  209967713        NaN
# 2018-06-20  17.095999  17.440329  16.364297  17.044348  198271914        NaN
# ...               ...        ...        ...        ...        ...        ...
# 2025-02-19  23.240000  23.639999  22.549999  22.600000  197765185        NaN
# 2025-02-20  22.620001  23.110001  22.580000  23.049999  148493316        NaN
# 2025-02-21  23.200001  23.299999  22.590000  22.870001  202636966        NaN
# 2025-02-24  23.209999  23.959999  22.799999  23.379999  236870254        NaN
# ...

# %%
df[['logrolling_mean','logvrolling_std']].plot(figsize=(20,8),style='b',subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
df[['logrolling_mean','logrolling_std']].plot(figsize=(20,8),style='b',subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1623 entries, 2018-06-13 to 2025-02-25
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   (Close, 601138.SS)    1623 non-null   float64
#  1   (High, 601138.SS)     1623 non-null   float64
#  2   (Low, 601138.SS)      1623 non-null   float64
#  3   (Open, 601138.SS)     1623 non-null   float64
#  4   (Volume, 601138.SS)   1623 non-null   int64
#  5   (simple_rtn, )        0 non-null      float64
#  6   (clog_rtn, )          0 non-null      float64
#  7   (vrolling_mean, )     1612 non-null   float64
#  8   (vrolling_std, )      1612 non-null   float64
#  9   (rolling_mean, )      1612 non-null   float64
#  10  (rolling_std, )       1612 non-null   float64
#  11  (logrolling_mean, )   1611 non-null   float64
#  12  (logrolling_std, )    1611 non-null   float64
#  13  (logvrolling_mean, )  1611 non-null   float64
# ...
